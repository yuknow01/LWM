# %% [markdown]
# # Option 2 Scene_split

# %%
import matplotlib.pyplot as plt

# Epoch indices
epochs = list(range(1, 51))

# Combined metrics for all models
metrics = {
    'LWM_Fine_tune': {
        'val_loss':   [0.0063, 0.0054, 0.0045, 0.0043, 0.0041, 0.0040, 0.0039, 0.0040, 0.0040, 0.0041,
                       0.0041, 0.0041, 0.0041, 0.0041, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042,
                       0.0042, 0.0042, 0.0042, 0.0042, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
                       0.0041, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040,
                       0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040],
        'val_rmse':   [0.0763, 0.0706, 0.0650, 0.0633, 0.0617, 0.0612, 0.0609, 0.0611, 0.0615, 0.0619,
                       0.0621, 0.0625, 0.0625, 0.0628, 0.0633, 0.0631, 0.0634, 0.0636, 0.0635, 0.0633,
                       0.0634, 0.0633, 0.0630, 0.0630, 0.0629, 0.0626, 0.0622, 0.0623, 0.0625, 0.0622,
                       0.0622, 0.0618, 0.0619, 0.0616, 0.0618, 0.0617, 0.0616, 0.0614, 0.0612, 0.0613,
                       0.0613, 0.0614, 0.0615, 0.0613, 0.0614, 0.0615, 0.0617, 0.0618, 0.0618, 0.0615],
        'val_nmse_db':[-16.3, -17.0, -17.7, -17.9, -18.2, -18.2, -18.3, -18.3, -18.2, -18.2,
                       -18.1, -18.1, -18.1, -18.0, -18.0, -18.0, -18.0, -17.9, -18.0, -18.0,
                       -18.0, -18.0, -18.0, -18.0, -18.0, -18.1, -18.1, -18.1, -18.1, -18.1,
                       -18.1, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.3, -18.2,
                       -18.3, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2],
    },
    'GRU': {
        'val_loss':   [0.0079, 0.0059, 0.0048, 0.0043, 0.0042, 0.0041, 0.0041, 0.0041, 0.0040, 0.0040,
                       0.0040, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
                       0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042,
                       0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043,
                       0.0043, 0.0043, 0.0043, 0.0043, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042],
        'val_rmse':   [0.0835, 0.0738, 0.0670, 0.0639, 0.0626, 0.0622, 0.0620, 0.0619, 0.0617, 0.0617,
                       0.0619, 0.0620, 0.0620, 0.0621, 0.0622, 0.0623, 0.0624, 0.0625, 0.0627, 0.0628,
                       0.0629, 0.0630, 0.0631, 0.0632, 0.0633, 0.0634, 0.0634, 0.0635, 0.0636, 0.0636,
                       0.0637, 0.0637, 0.0638, 0.0638, 0.0638, 0.0639, 0.0638, 0.0638, 0.0638, 0.0638,
                       0.0637, 0.0637, 0.0637, 0.0637, 0.0636, 0.0636, 0.0636, 0.0636, 0.0636, 0.0635],
        'val_nmse_db':[-15.4, -16.6, -17.5, -17.9, -18.0, -18.1, -18.1, -18.1, -18.2, -18.2,
                       -18.2, -18.1, -18.1, -18.1, -18.1, -18.1, -18.1, -18.1, -18.1, -18.0,
                       -18.0, -18.0, -18.0, -18.0, -18.0, -18.0, -18.0, -18.0, -17.9, -17.9,
                       -17.9, -17.9, -17.9, -17.9, -17.9, -17.9, -17.9, -17.9, -17.9, -17.9,
                       -17.9, -17.9, -17.9, -17.9, -17.9, -17.9, -17.9, -17.9, -17.9, -18.0],
    },
    'RNN': {
        'val_loss':   [0.0075, 0.0055, 0.0046, 0.0043, 0.0042, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
                       0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040,
                       0.0040, 0.0040, 0.0040, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
                       0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
                       0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0
            0.0607, 0.0610, 0.0608, 0.0609, 0.0610, 0.0611, 0.0607, 0.0610, 0.0610, 0.0608,
            0.0612, 0.0607, 0.0610, 0.0608, 0.0607, 0.0608, 0.0607, 0.0606, 0.0607, 0.0610
        ],
         'val_nmse_db': [
            -15.4, -16.3, -16.8, -16.9, -17.5, -17.7, -17.8, -17.8, -17.9, -17.9,
            -18.0, -18.0, -18.1, -18.1, -18.1, -18.2, -18.2, -18.2, -18.2, -18.2,
            -18.3, -18.3, -18.3, -18.3, -18.3, -18.2, -18.2, -18.2, -18.2, -18.2,
            -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2,
            -18.1, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.1
        ]
    }
}

# Font size settings
title_fontsize = 16
label_fontsize = 14
legend_fontsize = 12

# Create subplots for comparison
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)

# Validation Loss comparison
ax = axes[0]
for model, data in metrics.items():
    ax.plot(epochs, data['val_loss'], label=model, lw=2)
ax.set_xlabel('Epoch', fontsize=label_fontsize)
ax.set_ylabel('Validation Loss', fontsize=label_fontsize)
ax.set_title('Validation Loss Comparison', fontsize=title_fontsize)
ax.legend(fontsize=legend_fontsize)
ax.tick_params(axis='both', labelsize=label_fontsize)

# Validation RMSE comparison
ax = axes[1]
for model, data in metrics.items():
    ax.plot(epochs, data['val_rmse'], label=model, lw=2)
ax.set_xlabel('Epoch', fontsize=label_fontsize)
ax.set_ylabel('Validation RMSE', fontsize=label_fontsize)
ax.set_title('Validation RMSE Comparison', fontsize=title_fontsize)
ax.legend(fontsize=legend_fontsize)
ax.tick_params(axis='both', labelsize=label_fontsize)

# Validation NMSE (dB) comparison
ax = axes[2]
for model, data in metrics.items():
    ax.plot(epochs, data['val_nmse_db'], label=model, lw=2)
ax.set_xlabel('Epoch', fontsize=label_fontsize)
ax.set_ylabel('Validation NMSE (dB)', fontsize=label_fontsize)
ax.set_title('Validation NMSE (dB) Comparison', fontsize=title_fontsize)
ax.legend(fontsize=legend_fontsize,)
ax.tick_params(axis='both', labelsize=label_fontsize)

plt.tight_layout()
plt.show()

# %%
# Compute per-model lowest NMSE(dB) and overall lowest from the current `metrics` dict
import pandas as pd

epochs = list(range(1, 51))

rows = []
for model, data in metrics.items():
    nmse = data['val_nmse_db']
    min_val = min(nmse)                          # most negative (best) dB
    first_idx = nmse.index(min_val)              # first occurrence
    rows.append({
        "Model": model,
        "Min NMSE (dB)": min_val,
        "Epoch (1-indexed)": epochs[first_idx],
    })

summary_df = pd.DataFrame(rows).sort_values("Min NMSE (dB)").reset_index(drop=True)

# Overall lowest across all models
overall = None
for model, data in metrics.items():
    nmse = data['val_nmse_db']
    min_val = min(nmse)
    idx = nmse.index(min_val)
    if overall is None or min_val < overall["Min NMSE (dB)"]:
        overall = {"Model": model, "Epoch (1-indexed)": epochs[idx], "Min NMSE (dB)": min_val}
overall_df = pd.DataFrame([overall])

# Print as plain pandas DataFrames
print("Per-model Lowest Validation NMSE(dB)")
print(summary_df.to_string(index=False))

print("\nOverall Lowest Validation NMSE(dB)")
print(overall_df.to_string(index=False))
# Out:
# Per-model Lowest Validation NMSE(dB)
#                    Model  Min NMSE (dB)  Epoch (1-indexed)
#            LWM_Fine_tune          -18.3                  7
# LWM_pretrained_Fine_tune          -18.3                 21
#                      RNN          -18.2                 10
#                      GRU          -18.2                  9
#                     LSTM          -18.2                 18
#      LWM_freeze_backbone          -16.0                 42
#              Transformer          -15.8                 49
#
# Overall Lowest Validation NMSE(dB)
#         Model  Epoch (1-indexed)  Min NMSE (dB)
# LWM_Fine_tune                  7          -18.3

# %%
import matplotlib.pyplot as plt

# Epoch indices
epochs = list(range(1, 51))

# Combined metrics for each model including train_loss
metrics = {
    'LWM_FromScratch': {
        'train_loss': [
            0.0103, 0.0032, 0.0023, 0.0019, 0.0017, 0.0016, 0.0015, 0.0015, 0.0014, 0.0014,
            0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012,
            0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0011,
            0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
            0.0011, 0.0011, 0.0011, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010
        ],
        'val_loss': [
            0.0063, 0.0054, 0.0045, 0.0043, 0.0041, 0.0040, 0.0039, 0.0040, 0.0040, 0.0041,
            0.0041, 0.0041, 0.0041, 0.0041, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042,
            0.0042, 0.0042, 0.0042, 0.0042, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
            0.0041, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040,
            0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040
        ],
        'val_rmse': [
            0.0763, 0.0706, 0.0650, 0.0633, 0.0617, 0.0612, 0.0609, 0.0611, 0.0615, 0.0619,
            0.0621, 0.0625, 0.0625, 0.0628, 0.0633, 0.0631, 0.0634, 0.0636, 0.0635, 0.0633,
            0.0634, 0.0633, 0.0630, 0.0630, 0.0629, 0.0626, 0.0622, 0.0623, 0.0625, 0.0622,
            0.0622, 0.0618, 0.0619, 0.0616, 0.0618, 0.0617, 0.0616, 0.0614, 0.0612, 0.0613,
            0.0613, 0.0614, 0.0615, 0.0613, 0.0614, 0.0615, 0.0617, 0.0618, 0.0618, 0.0615
        ],
        'val_nmse_db': [
            -16.3, -17.0, -17.7, -17.9, -18.2, -18.2, -18.3, -18.3, -18.2, -18.2,
            -18.1, -18.1, -18.1, -18.0, -18.0, -18.0, -18.0, -17.9, -18.0, -18.0,
            -18.0, -18.0, -18.0, -18.0, -18.0, -18.1, -18.1, -18.1, -18.1, -18.1,
            -18.1, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.3, -18.2,
            -18.3, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2
        ]
    },
    'LWM_Freeze': {
        'train_loss': [
            0.0584, 0.0076, 0.0074, 0.0072, 0.0069, 0.0065, 0.0062, 0.0059, 0.0057, 0.0056,
            0.0055, 0.0054, 0.0054, 0.0054, 0.0053, 0.0053, 0.0052, 0.0052, 0.0052, 0.0052,
            0.0052, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.0050, 0.0050, 0.0050, 0.0050,
            0.0050, 0.0050, 0.0049, 0.0049, 0.0049, 0.0049, 0.0049, 0.0048, 0.0048, 0.0048,
            0.0048, 0.0047, 0.0047, 0.0047, 0.0047, 0.0046, 0.0046, 0.0046, 0.0046, 0.0045
        ],
        'val_loss': [
            0.0091, 0.0093, 0.0092, 0.0089, 0.0086, 0.0083, 0.0080, 0.0078, 0.0077, 0.0076,
            0.0076, 0.0075, 0.0075, 0.0075, 0.0075, 0.0074, 0.0074, 0.0074, 0.0074, 0.0074,
18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2,
            -18.1, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.2, -18.1
        ]
    }
}
# grid plus
# Marker styles for each model
markers = ['o', 's', '^']

# Font size settings
title_fontsize = 25
label_fontsize = 20
legend_fontsize = 20

# Create 4 subplots for train_loss, val_loss, val_rmse, val_nmse_db
fig, axes = plt.subplots(2, 1, figsize=(8, 10), sharex=True)

# Train Loss
axes[0].set_title('Scene Train Loss Comparison', fontsize=title_fontsize)
for (name, m), marker in zip(metrics.items(), markers):
    axes[0].plot(epochs, m['train_loss'], label=name, lw=2, marker=marker, markevery=5)
axes[0].set_ylabel('Train Loss', fontsize=label_fontsize)
axes[0].legend(fontsize=legend_fontsize)
axes[0].tick_params(axis='both', labelsize=label_fontsize)

# Validation Loss
axes[1].set_title('Scene Validation Loss Comparison', fontsize=title_fontsize)
for (name, m), marker in zip(metrics.items(), markers):
    axes[1].plot(epochs, m['val_loss'], label=name, lw=2, marker=marker, markevery=5)
axes[1].set_ylabel('Val Loss', fontsize=label_fontsize)
axes[1].legend(fontsize=legend_fontsize)
axes[1].tick_params(axis='both', labelsize=label_fontsize)


# X-axis settings for all subplots
for ax in axes:
    ax.set_xticks([10, 20, 30, 40, 50])
    ax.tick_params(axis='x', which='both', labelbottom=True)

# Only bottom subplot has the x-axis label
axes[-1].set_xlabel('Epoch', fontsize=label_fontsize)

plt.tight_layout()
plt.show()
# Out:
# /home/dlghdbs200/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
import matplotlib.pyplot as plt

# Epoch indices
epochs = list(range(1, 151))

# Combined metrics for each model including train_loss
metrics = {
    'LWM_FromScratch': {
        'train_loss': [
            0.0144, 0.0043, 0.0027, 0.0021, 0.0018, 0.0017, 0.0016, 0.0015, 0.0015, 0.0014,
            0.0014, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012, 0.0012,
            0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0011, 0.0011, 0.0011, 0.0011,
            0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0010, 0.0010, 0.0010,
            0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
            0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
            0.0009, 0.0009, 0.0009, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
            0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0007, 0.0007, 0.0007,
            0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 
            0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
            0.0006, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005,
            0.0006, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 
        ],
        'val_loss': [
            0.0071, 0.0056, 0.0048, 0.0045, 0.0043, 0.0043, 0.0042, 0.0042, 0.0042, 0.0042,
            0.0042, 0.0042, 0.0042, 0.0042, 0.0043, 0.0042, 0.0043, 0.0042, 0.0043, 0.0042,
            0.0042, 0.0042, 0.0042, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0040, 0.0041,
            0.0041, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 
            0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 
            0.0040, 0.0040, 0.0040, 0.0040, 0.0041, 0.0040, 0.0040, 0.0041, 0.0041, 0.0041,
            0.0041, 0.0040, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
            0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
            0.0041, 0.0041, 0.0041, 0.0042, 0.0042, 0.0041, 0.0042, 0.0042, 0.0042, 0.0042,
            0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042,
            0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0
 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0015, 0.0015,
            0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0014, 0.0014,
            0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014,
            0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
            0.0013, 0.0013, 0.0013, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
            0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0011,
            0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
            0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0010,
            0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
            0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
            0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0009, 0.0009, 0.0009, 0.0009,
            0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
            0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
        ],
        'val_loss': [
            0.0080, 0.0070, 0.0064, 0.0058, 0.0054, 0.0051, 0.0050, 0.0049, 0.0048, 0.0048,
            0.0047, 0.0047, 0.0047, 0.0047, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046,
            0.0046, 0.0046, 0.0045, 0.0045, 0.0045, 0.0045, 0.0044, 0.0044, 0.0044, 0.0044,
            0.0044, 0.0044, 0.0043, 0.0044, 0.0043, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044,
            0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044,
            0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044,
            0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0046, 0.0046,
            0.0046, 0.0045, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0047, 0.0047,
            0.0047, 0.0047, 0.0047, 0.0048, 0.0048, 0.0047, 0.0048, 0.0047, 0.0048, 0.0048,
            0.0048, 0.0047, 0.0048, 0.0047, 0.0047, 0.0048, 0.0047, 0.0048, 0.0048, 0.0048,
            0.0047, 0.0047, 0.0048, 0.0048, 0.0048, 0.0047, 0.0048, 0.0048, 0.0048, 0.0048,
            0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0048, 0.0047, 0.0048, 0.0047, 0.0047,
            0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047,
            0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047,
            0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0046, 0.0047,
        ]
        
    }
}
# grid plus
# Marker styles for each model
markers = ['o', 's', '^']

# Font size settings
title_fontsize = 25
label_fontsize = 20
legend_fontsize = 20

# Create 4 subplots for train_loss, val_loss, val_rmse, val_nmse_db
fig, axes = plt.subplots(2, 1, figsize=(8, 10), sharex=True)

# Train Loss
axes[0].set_title('Scene Train Loss Comparison', fontsize=title_fontsize)
for (name, m), marker in zip(metrics.items(), markers):
    axes[0].plot(epochs, m['train_loss'], label=name, lw=2, marker=marker, markevery=5)
axes[0].set_ylabel('Train Loss', fontsize=label_fontsize)
axes[0].legend(fontsize=legend_fontsize)
axes[0].tick_params(axis='both', labelsize=label_fontsize)

# Validation Loss
axes[1].set_title('Scene Validation Loss Comparison', fontsize=title_fontsize)
for (name, m), marker in zip(metrics.items(), markers):
    axes[1].plot(epochs, m['val_loss'], label=name, lw=2, marker=marker, markevery=5)
axes[1].set_ylabel('Val Loss', fontsize=label_fontsize)
axes[1].legend(fontsize=legend_fontsize)
axes[1].tick_params(axis='both', labelsize=label_fontsize)


# X-axis settings for all subplots
for ax in axes:
    ax.set_xticks([10, 40, 70, 110, 150])
    ax.tick_params(axis='x', which='both', labelbottom=True)

# Only bottom subplot has the x-axis label
axes[-1].set_xlabel('Epoch', fontsize=label_fontsize)

plt.tight_layout()
plt.show()

# %%
# Inference-time summary with only total/batch/sample columns (sorted by per-sample)

import pandas as pd

rows = [
    {"Model": "GRU",                      "Total (s)": 33.23, "Per-batch (ms)": 67.26,  "Per-sample (ms)": 0.26},
    {"Model": "RNN",                      "Total (s)": 33.33, "Per-batch (ms)": 67.47,  "Per-sample (ms)": 0.26},
    {"Model": "LSTM",                     "Total (s)": 34.08, "Per-batch (ms)": 69.00,  "Per-sample (ms)": 0.27},
    {"Model": "Transformer",              "Total (s)": 39.09, "Per-batch (ms)": 79.12,  "Per-sample (ms)": 0.31},
    {"Model": "LWM_Fine_tune",            "Total (s)": 44.85, "Per-batch (ms)": 90.79,  "Per-sample (ms)": 0.35},
    {"Model": "LWM_freeze_backbone",      "Total (s)": 80.55, "Per-batch (ms)": 163.05, "Per-sample (ms)": 0.64},
    {"Model": "LWM_pretrained_Fine_tune", "Total (s)": 81.28, "Per-batch (ms)": 164.53, "Per-sample (ms)": 0.64},
]

df = pd.DataFrame(rows).sort_values("Per-sample (ms)", ascending=True).reset_index(drop=True)

# Nice rounding
for c in ["Total (s)", "Per-batch (ms)", "Per-sample (ms)"]:
    df[c] = df[c].round(2)

# Keep only requested columns (plus Model for identification)
df = df[["Model", "Total (s)", "Per-batch (ms)", "Per-sample (ms)"]]

print("=== Inference-time summary (combined) ===")
print(df.to_string(index=False))
# Out:
# === Inference-time summary (combined) ===
#                    Model  Total (s)  Per-batch (ms)  Per-sample (ms)
#                      GRU      33.23           67.26             0.26
#                      RNN      33.33           67.47             0.26
#                     LSTM      34.08           69.00             0.27
#              Transformer      39.09           79.12             0.31
#            LWM_Fine_tune      44.85           90.79             0.35
#      LWM_freeze_backbone      80.55          163.05             0.64
# LWM_pretrained_Fine_tune      81.28          164.53             0.64

# %% [markdown]
# # Option 2 -> Option1 change

# %%
import matplotlib.pyplot as plt

# Epoch indices
epochs = list(range(1, 51))

# --- LSTM (values from the latest screenshot) ---
lstm_train_loss = [
    0.0185, 0.0046, 0.0032, 0.0025, 0.0022, 0.0019, 0.0018, 0.0017, 0.0016, 0.0016,
    0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014,
    0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014,
    0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013
]
lstm_val_loss = [
    0.0045, 0.0035, 0.0028, 0.0022, 0.0019, 0.0017, 0.0016, 0.0016, 0.0015, 0.0015,
    0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011
]
lstm_val_nmse_db = [
    -17.7, -18.8, -19.8, -20.8, -21.4, -21.8, -22.0, -22.2, -22.4, -22.5,
    -22.6, -22.7, -22.8, -22.9, -22.9, -22.9, -22.9, -23.0, -23.0, -23.0,
    -23.0, -23.0, -23.0, -23.0, -23.0, -23.1, -23.1, -23.1, -23.1, -23.1,
    -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1,
    -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1
]
# approximate RMSE from val_nmse? use previous values
lstm_val_rmse = [
    0.0616, 0.0546, 0.0487, 0.0436, 0.0405, 0.0382, 0.0370, 0.0362, 0.0355, 0.0349,
    0.0344, 0.0340, 0.0336, 0.0332, 0.0331, 0.0329, 0.0328, 0.0324, 0.0326, 0.0325,
    0.0325, 0.0324, 0.0324, 0.0323, 0.0323, 0.0323, 0.0322, 0.0322, 0.0323, 0.0323,
    0.0323, 0.0322, 0.0322, 0.0322, 0.0322, 0.0321, 0.0321, 0.0320, 0.0320, 0.0320,
    0.0320, 0.0320, 0.0320, 0.0319, 0.0319, 0.0319, 0.0319, 0.0319, 0.0319, 0.0318
]

# --- Transformer (values from screenshot) ---
transformer_train_loss = [
    0.0078, 0.0018, 0.0015, 0.0015, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0011,
    0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0010, 0.0010, 0.0010, 0.0010,
    0.0010, 0.0010, 0.0010, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
    0.0009, 0.0009, 0.0009, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008
]
transformer_val_loss = [
    0.0021, 0.0015, 0.0015, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
    0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010
]
transformer_val_rmse = [
    0.1864, 0.1846, 0.1732, 0.1638, 0.1558, 0.1483, 0.1418, 0.1363, 0.1308, 0.1259,
    0.1214, 0.1172, 0.1139, 0.1108, 0.1075, 0.1038, 0.0999, 0.0961, 0.0926, 0.0899,
    0.0876, 0.0853, 0.0833, 0.0817, 0.0804, 0.0795, 0.0784, 0.0773, 0.0765, 0.0757,
    0.0742, 0.0730, 0.0714, 0.0704, 0.0693, 0.0680, 0.0668, 0.0654, 0.0648, 0.0638,
    0.0650, 0.0651, 0.0671, 0.0647, 0.0669, 0.0668, 0.0666, 0.0654, 0.0663, 0.0663
]
transformer_val_nmse_db = [
    -8.7, -8.7, -9.3, -9.8, -10.2, -10.6, -11.0, -11.4, -11.7, -12.1,
    -12.4, -12.7, -12.9, -13.2, -13.4, -13.7, -14.1, -14.4, -14.7, -15.0,
    -15.2, -15.4, -15.6, -15.8, -15.9, -16.0, -16.1, -16.2, -16.3, -16.4,
    -16.6, -16.7, -16.9, -17.1, -17.2, -17.3, -17.5, -17.7, -17.9, -17.9,
    -18.0, -17.7, -17.7, -17.5, -17.8, -17.5, -17.5, -17.5, -17.7, -17.5
]
gru_train_loss = [
    0.0139, 0.0033, 0.0021, 0.0016, 0.0015, 0.0015, 0.0015, 0.0015, 0.0014, 0.0014,
    0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014,
    0.0014, 0.0014, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013
]
rnn_train_loss = [
    0.0133, 0.0037, 0.0021, 0.0016, 0.0015, 0.0015, 0.0015, 0.0014, 0.0014, 0.0014,
    0.0014, 0.0014, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013
]

# GRU validation metrics
gru_val_loss = [
    0.0039, 0.0024, 0.0017, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012
]
rnn_val_loss = [
    0.0043, 0.0026, 0.0016, 0.0015, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012
]

# Validation RMSE and NMSE(dB)
gru_val_rmse = [
    0.0568, 0.0445, 0.0375, 0.0345, 0.0337, 0.0335, 0.0334, 0.0333, 0.0331, 0.0328,
    0.0325, 0.0323, 0.0321, 0.0320, 0.0319, 0.0319, 0.0318, 0.0317, 0.0317, 0.0317,
    0.0316, 0.0316, 0.0315, 0.0315, 0.0315, 0.0314, 0.0314, 0.0314, 0.0313, 0.0313,
    0.0313, 0.0312, 0.0312, 0.0312, 0.0311, 0.0311, 0.0311, 0.0310, 0.0310, 0.0309,
    0.0309, 0.0308, 0.0308, 0.0308, 0.0307, 0.0307, 0.0307, 0.0307, 0.0306, 0.0306
]
rnn_val_rmse = [
 0.0017, 0.0017, 0.0017, 0.0017, 0.0017,
    0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0015, 0.0015, 0.0015,
    0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0014, 0.0014, 0.0014,
    0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014
]
val_loss_pt = [
    0.0104, 0.0081, 0.0068, 0.0059, 0.0056, 0.0053, 0.0053, 0.0052, 0.0052, 0.0051,
    0.0052, 0.0052, 0.0052, 0.0051, 0.0052, 0.0052, 0.0052, 0.0052, 0.0050, 0.0051,
    0.0050, 0.0050, 0.0050, 0.0049, 0.0050, 0.0049, 0.0050, 0.0049, 0.0050, 0.0050,
    0.0050, 0.0050, 0.0050, 0.0050, 0.0050, 0.0049, 0.0049, 0.0049, 0.0049, 0.0050,
    0.0050, 0.0050, 0.0050, 0.0049, 0.0049, 0.0049, 0.0050, 0.0049, 0.0050, 0.0050
]
val_rmse_pt = [
    0.0964, 0.0854, 0.0790, 0.0743, 0.0726, 0.0712, 0.0711, 0.0703, 0.0703, 0.0700,
    0.0705, 0.0702, 0.0706, 0.0700, 0.0706, 0.0710, 0.0707, 0.0706, 0.0694, 0.0698,
    0.0692, 0.0696, 0.0693, 0.0688, 0.0690, 0.0687, 0.0692, 0.0690, 0.0692, 0.0691,
    0.0691, 0.0692, 0.0693, 0.0690, 0.0690, 0.0688, 0.0693, 0.0690, 0.0689, 0.0691,
    0.0692, 0.0691, 0.0692, 0.0691, 0.0691, 0.0693, 0.0691, 0.0692, 0.0691, 0.0691
]
val_nmse_pt = [
    -14.3, -15.4, -16.1, -16.7, -16.9, -17.1, -17.1, -17.2, -17.2, -17.2,
    -17.2, -17.2, -17.1, -17.2, -17.2, -17.1, -17.2, -17.2, -17.3, -17.3,
    -17.3, -17.3, -17.3, -17.4, -17.4, -17.4, -17.3, -17.4, -17.3, -17.3,
    -17.3, -17.3, -17.3, -17.3, -17.3, -17.4, -17.3, -17.4, -17.4, -17.3,
    -17.3, -17.3, -17.4, -17.4, -17.4, -17.4, -17.4, -17.4, -17.3, -17.4
]


# 1) Validation-NMSE(dB) lists for each model
metrics = {
    'LSTM': {
        'train_loss': lstm_train_loss,
        'val_loss': lstm_val_loss,
        'val_rmse': lstm_val_rmse,
        'val_nmse_db': lstm_val_nmse_db,
    },
    'GRU': {
        'train_loss': gru_train_loss,
        'val_loss': gru_val_loss,
        'val_rmse': gru_val_rmse,
        'val_nmse_db': gru_val_nmse_db,
    },
    'RNN': {
        'train_loss': rnn_train_loss,
        'val_loss': rnn_val_loss,
        'val_rmse': rnn_val_rmse,
        'val_nmse_db': rnn_val_nmse_db,
    },
    'Transformer': {
        'train_loss': transformer_train_loss,
        'val_loss': transformer_val_loss,
        'val_rmse': transformer_val_rmse,
        'val_nmse_db': transformer_val_nmse_db,
    },
    'LWM Fine-tune': {
        'train_loss': train_loss_ft,
        'val_loss': val_loss_ft,
        'val_rmse': val_rmse_ft,
        'val_nmse_db': val_nmse_ft,
    },
    'LWM Freeze-backbone': {
        'train_loss': train_loss_fb,
        'val_loss': val_loss_fb,
        'val_rmse': val_rmse_fb,
        'val_nmse_db': val_nmse_fb,
    },
    'LWM Pretrained Fine-tune': {
        'train_loss': train_loss_pt,
        'val_loss': val_loss_pt,
        'val_rmse': val_rmse_pt,
        'val_nmse_db': val_nmse_pt,
    },
}


# Matplotlib style settings for publication
title_fontsize = 16
label_fontsize = 14
legend_fontsize = 12



# Create subplots for comparison
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)



# Common plotting function
# Validation Loss comparison
ax = axes[0]
for model, data in metrics.items():
    ax.plot(epochs, data['val_loss'], label=model, lw=2)
ax.set_xlabel('Epoch', fontsize=label_fontsize)
ax.set_ylabel('Validation Loss', fontsize=label_fontsize)
ax.set_title('Validation Loss Comparison', fontsize=title_fontsize)
ax.legend(fontsize=legend_fontsize)
ax.tick_params(axis='both', labelsize=label_fontsize)

# Validation RMSE comparison
ax = axes[1]
for model, data in metrics.items():
    ax.plot(epochs, data['val_rmse'], label=model, lw=2)
ax.set_xlabel('Epoch', fontsize=label_fontsize)
ax.set_ylabel('Validation RMSE', fontsize=label_fontsize)
ax.set_title('Validation RMSE Comparison', fontsize=title_fontsize)
ax.legend(fontsize=legend_fontsize)
ax.tick_params(axis='both', labelsize=label_fontsize)

# Validation NMSE (dB) comparison
ax = axes[2]
for model, data in metrics.items():
    ax.plot(epochs, data['val_nmse_db'], label=model, lw=2)
ax.set_xlabel('Epoch', fontsize=label_fontsize)
ax.set_ylabel('Validation NMSE (dB)', fontsize=label_fontsize)
ax.set_title('Validation NMSE (dB) Comparison', fontsize=title_fontsize)
ax.legend(fontsize=legend_fontsize)
ax.tick_params(axis='both', labelsize=label_fontsize)

plt.tight_layout()
plt.show()

# %%
# Recreate the NMSE(dB) series, compute per-model *lowest* (most negative) values,
# and display them as plain pandas DataFrames (no ChatGPT-specific helpers).

import pandas as pd

epochs = list(range(1, 51))

# NMSE(dB) series
lstm_val_nmse_db = [
    -17.7, -18.8, -19.8, -20.8, -21.4, -21.8, -22.0, -22.2, -22.4, -22.5,
    -22.6, -22.7, -22.8, -22.9, -22.9, -22.9, -22.9, -23.0, -23.0, -23.0,
    -23.0, -23.0, -23.0, -23.0, -23.0, -23.1, -23.1, -23.1, -23.1, -23.1,
    -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1,
    -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1
]
gru_val_nmse_db = [
    -18.4, -20.5, -22.0, -22.6, -22.8, -22.8, -22.8, -22.9, -22.9, -23.0,
    -23.0, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.2, -23.2, -23.2,
    -23.2, -23.2, -23.2, -23.2, -23.2, -23.2, -23.2, -23.2, -23.3, -23.3,
    -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3,
    -23.3, -23.4, -23.4, -23.4, -23.4, -23.4, -23.4, -23.4, -23.4, -23.4
]
rnn_val_nmse_db = [
    -18.0, -20.1, -22.1, -22.6, -22.7, -22.8, -22.9, -23.0, -23.0, -23.1,
    -23.1, -23.1, -23.1, -23.1, -23.2, -23.2, -23.2, -23.2, -23.2, -23.2,
    -23.2, -23.2, -23.2, -23.2, -23.2, -23.3, -23.3, -23.3, -23.3, -23.3,
    -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3,
    -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3
]
transformer_val_nmse_db = [
    -8.7, -8.7, -9.3, -9.8, -10.2, -10.6, -11.0, -11.4, -11.7, -12.1,
    -12.4, -12.7, -12.9, -13.2, -13.4, -13.7, -14.1, -14.4, -14.7, -15.0,
    -15.2, -15.4, -15.6, -15.8, -15.9, -16.0, -16.1, -16.2, -16.3, -16.4,
    -16.6, -16.7, -16.9, -17.1, -17.2, -17.3, -17.5, -17.7, -17.9, -17.9,
    -18.0, -17.7, -17.7, -17.5, -17.8, -17.5, -17.5, -17.5, -17.7, -17.5
]
val_nmse_ft = [
    -14.6, -15.8, -16.7, -17.4, -17.4, -17.3, -17.1, -17.0, -16.8, -16.6, -16.6, -16.6,
    -16.5, -16.5, -16.4, -16.4, -16.4, -16.4, -16.4, -16.4, -16.4, -16.4, -16.3, -16.4,
    -16.3, -16.3, -16.3, -16.3, -16.2, -16.3, -16.2, -16.2, -16.2, -16.2, -16.2, -16.2,
    -16.2, -16.2, -16.2, -16.1, -16.2, -16.2, -16.1, -16.2, -16.2, -16.2, -16.2, -16.2,
    -16.2, -16.2
]
val_nmse_fb = [
    -13.2, -13.2, -13.2, -13.3, -13.4, -13.6, -13.8, -13.8, -13.9, -14.0,
    -14.0, -14.0, -14.1, -14.1, -14.1, -14.1, -14.1, -14.2, -14.2, -14.2,
    -14.2, -14.2, -14.3, -14.3, -14.3, -14.3, -14.3, -14.4, -14.4, -14.4,
    -14.5, -14.5, -14.5, -14.5, -14.6, -14.6, -14.6, -14.6, -14.6, -14.7,
    -14.7, -14.7, -14.7, -14.7, -14.7, -14.7, -14.8, -14.8, -14.8, -14.8
]
val_nmse_pt = [
    -14.3, -15.4, -16.1, -16.7, -16.9, -17.1, -17.1, -17.2, -17.2, -17.2,
    -17.2, -17.2, -17.1, -17.2, -17.2, -17.1, -17.2, -17.2, -17.3, -17.3,
    -17.3, -17.3, -17.3, -17.4, -17.4, -17.4, -17.3, -17.4, -17.3, -17.3,
    -17.3, -17.3, -17.3, -17.3, -17.3, -17.4, -17.3, -17.4, -17.4, -17.3,
    -17.3, -17.3, -17.4, -17.4, -17.4, -17.4, -17.4, -17.4, -17.3, -17.4
]

val_nmse_db_by_model = {
    'LSTM': lstm_val_nmse_db,
    'GRU': gru_val_nmse_db,
    'RNN': rnn_val_nmse_db,
    'Transformer': transformer_val_nmse_db,
    'LWM Fine-tune': val_nmse_ft,
    'LWM Freeze-backbone': val_nmse_fb,
    'LWM Pretrained Fine-tune': val_nmse_pt,
}

# Build per-model summary: lowest (min) NMSE(dB) and the 1-indexed epoch (first occurrence)
rows = []
for model, series in val_nmse_db_by_model.items():
    min_val = min(series)
    epoch_of_min = epochs[series.index(min_val)]
    rows.append({
        "Model": model,
        "Min NMSE (dB)": min_val,
        "Epoch (1-indexed)": epoch_of_min
    })

summary_df = pd.DataFrame(rows).sort_values("Min NMSE (dB)", ascending=True).reset_index(drop=True)

# Compute the overall lowest NMSE(dB) across all models/epochs
overall = None
for model, series in val_nmse_db_by_model.items():
    min_val = min(series)
    idx = series.index(min_val)
    if (overall is None) or (min_val < overall["Min NMSE (dB)"]):
        overall = {"Model": model, "Epoch (1-indexed)": epochs[idx], "Min NMSE (dB)": min_val}

overall_df = pd.DataFrame([overall])

# Print as plain pandas DataFrames (Notebook/console-friendly)
print("Per-model Lowest Validation NMSE(dB)")
print(summary_df.to_string(index=False))

print("\nOverall Lowest Validation NMSE(dB)")
print(overall_df.to_string(index=False))
# Out:
# Per-model Lowest Validation NMSE(dB)
#                    Model  Min NMSE (dB)  Epoch (1-indexed)
#                      GRU          -23.4                 42
#                      RNN          -23.3                 26
#                     LSTM          -23.1                 26
#              Transformer          -18.0                 41
#            LWM Fine-tune          -17.4                  4
# LWM Pretrained Fine-tune          -17.4                 24
#      LWM Freeze-backbone          -14.8                 47
#
# Overall Lowest Validation NMSE(dB)
# Model  Epoch (1-indexed)  Min NMSE (dB)
#   GRU                 42          -23.4

# %%
import matplotlib.pyplot as plt

# Epoch indices
epochs = list(range(1, 151))

# Combined metrics for each model including train_loss
metrics = {
    'LWM_FromScratch': {
        'train_loss': [
            0.0137, 0.0044, 0.0026, 0.0020, 0.0018, 0.0017, 0.0016, 0.0015, 0.0015, 0.0015,
            0.0014, 0.0014, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
            0.0013, 0.0013, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
            0.0012, 0.0012, 0.0012, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
            0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0010, 0.0010, 0.0010, 0.0010,
            0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0009,
            0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
            0.0009, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
            0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
            0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
            0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005,
            
        ],
        'val_loss': [
            0.0099, 0.0052, 0.0039, 0.0036, 0.0034, 0.0033, 0.0033, 0.0032, 0.0032, 0.0032,
            0.0033, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0035, 0.0035,
            0.0035, 0.0034, 0.0035, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034,
            0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034,
            0.0034, 0.0034, 0.0034, 0.0035, 0.0036, 0.0036, 0.0035, 0.0035, 0.0037, 0.0046,
            0.0043, 0.0043, 0.0033, 0.0033, 0.0033, 0.0034, 0.0033, 0.0033, 0.0033, 0.0033,
            0.0033, 0.0032, 0.0033, 0.0032, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033,
            0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033,
            0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0033,
            0.0033, 0.0033, 0.0033, 0.0033, 0.0033, 0.0034, 0.0034, 0.0034, 0.0033, 0.0034,
            0.0033, 0.0034, 0.0033, 0.0033, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 
            0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034,
            0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0034, 0.0035, 0.0035, 0.0035,
            0.0035, 0.0034, 0.0034, 0.0034, 0.0034, 0.0035, 0.0035, 0.0035, 0.0035, 0.0035,
            0.0034, 0.0035, 0.0035, 0.0035, 0.0034, 0.0035, 0.0035, 0.0034, 0.0035, 0.0034,
         ],
        
    },
    'LWM_Freeze': {
        'train_loss': [
            0.0589, 0.0080, 0.0079, 0.0078, 0.0077, 0.0074, 0.0070, 0.0067, 0.0065, 0.0063,
            0.0062, 0.0061, 0.0061, 0.0060, 0.0059, 0.0059, 0.0059, 0.0058, 0.0058, 0.0058,
            0.0058, 0.0057, 0.0057, 0.0057, 0.0057, 0.0056, 0.0056, 0.0056, 0.0055, 0.0055,
            0.0055, 0.0055, 0.0054, 0.0054, 0.0054, 0.0053, 0.0053, 0.0053, 0.0053, 0.0052,
            0.0052, 0.0052, 0.0052, 0.0052, 0.0051, 0.0051, 0.0051, 0.0051, 0.0051, 0.
 0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0023, 0.0023,
            0.0024, 0.0023, 0.0024, 0.0023, 0.0023, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024,
            0.0024, 0.0024, 0.0024, 0.0023, 0.0024, 0.0024, 0.0024, 0.0023, 0.0024, 0.0024,
            0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0023,
            0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0023,
        ]
        
    }
}
# grid plus
# Marker styles for each model
markers = ['o', 's', '^']

# Font size settings
title_fontsize = 25
label_fontsize = 20
legend_fontsize = 20

# Create 4 subplots for train_loss, val_loss, val_rmse, val_nmse_db
fig, axes = plt.subplots(2, 1, figsize=(8, 10), sharex=True)

# Train Loss
axes[0].set_title('User Train Loss Comparison', fontsize=title_fontsize)
for (name, m), marker in zip(metrics.items(), markers):
    axes[0].plot(epochs, m['train_loss'], label=name, lw=2, marker=marker, markevery=5)
axes[0].set_ylabel('Train Loss', fontsize=label_fontsize)
axes[0].legend(fontsize=legend_fontsize)
axes[0].tick_params(axis='both', labelsize=label_fontsize)

# Validation Loss
axes[1].set_title('User Validation Loss Comparison', fontsize=title_fontsize)
for (name, m), marker in zip(metrics.items(), markers):
    axes[1].plot(epochs, m['val_loss'], label=name, lw=2, marker=marker, markevery=5)
axes[1].set_ylabel('Val Loss', fontsize=label_fontsize)
axes[1].legend(fontsize=legend_fontsize)
axes[1].tick_params(axis='both', labelsize=label_fontsize)


# X-axis settings for all subplots
for ax in axes:
    ax.set_xticks([10, 40, 70, 110, 150])
    ax.tick_params(axis='x', which='both', labelbottom=True)

# Only bottom subplot has the x-axis label
axes[-1].set_xlabel('Epoch', fontsize=label_fontsize)

plt.tight_layout()
plt.show()

# %% [markdown]
# # inference

# %%
from tabulate import tabulate

# Combine both tables into one dataset
data_all = [
    # Second image (LWM_Fine_tune + GRU + RNN + LSTM + Transformer)
    ["LWM_Fine_tune", 43.93, 83.04, 0.32],
    ["GRU", 32.07, 60.62, 0.24],
    ["RNN", 31.36, 59.29, 0.23],
    ["LSTM", 32.57, 61.56, 0.24],
    ["Transformer", 32.05, 60.59, 0.24],

    # First image (LWM_freeze_backbone + LWM_pretrained_Fine_tune)
    ["LWM_freeze_backbone", 69.51, 128.25, 0.50],
    ["LWM_pretrained_Fine_tune", 69.34, 127.94, 0.50],
]

# Column headers
headers = ["model", "total [s]", "/batch [ms]", "/sample [ms]"]

# Print the combined inference-time summary table
print("=== Inference-time summary ===")
print(tabulate(data_all, headers, tablefmt="github"))
# Out:
# === Inference-time summary ===
# | model                    |   total [s] |   /batch [ms] |   /sample [ms] |
# |--------------------------|-------------|---------------|----------------|
# | LWM_Fine_tune            |       43.93 |         83.04 |           0.32 |
# | GRU                      |       32.07 |         60.62 |           0.24 |
# | RNN                      |       31.36 |         59.29 |           0.23 |
# | LSTM                     |       32.57 |         61.56 |           0.24 |
# | Transformer              |       32.05 |         60.59 |           0.24 |
# | LWM_freeze_backbone      |       69.51 |        128.25 |           0.5  |
# | LWM_pretrained_Fine_tune |       69.34 |        127.94 |           0.5  |

# %% [markdown]
# # Option3

# %%
import matplotlib.pyplot as plt

# ----- Epoch indices -----
epochs = list(range(1, 51))

# ---------------------------
# Raw series (as you provided)
# ---------------------------

# GRU
gru_val_loss = [
    0.0039, 0.0024, 0.0017, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012
]
gru_val_rmse = [
    0.0568, 0.0445, 0.0375, 0.0345, 0.0337, 0.0335, 0.0334, 0.0333, 0.0331, 0.0328,
    0.0325, 0.0323, 0.0321, 0.0320, 0.0319, 0.0319, 0.0318, 0.0317, 0.0317, 0.0317,
    0.0316, 0.0316, 0.0315, 0.0315, 0.0315, 0.0314, 0.0314, 0.0314, 0.0313, 0.0313,
    0.0313, 0.0312, 0.0312, 0.0312, 0.0311, 0.0311, 0.0311, 0.0310, 0.0310, 0.0309,
    0.0309, 0.0308, 0.0308, 0.0308, 0.0307, 0.0307, 0.0307, 0.0307, 0.0306, 0.0306
]
gru_val_nmse_db = [
    -18.4, -20.5, -22.0, -22.6, -22.8, -22.8, -22.8, -22.9, -22.9, -23.0,
    -23.0, -23.1, -23.1, -23.1, -23.1, -23.1, -23.1, -23.2, -23.2, -23.2,
    -23.2, -23.2, -23.2, -23.2, -23.2, -23.2, -23.2, -23.2, -23.3, -23.3,
    -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3,
    -23.3, -23.4, -23.4, -23.4, -23.4, -23.4, -23.4, -23.4, -23.4, -23.4
]

# RNN
rnn_val_loss = [
    0.0043, 0.0026, 0.0016, 0.0015, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
    0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012
]
rnn_val_rmse = [
    0.0594, 0.0465, 0.0371, 0.0347, 0.0339, 0.0334, 0.0329, 0.0326, 0.0323, 0.0321,
    0.0320, 0.0319, 0.0318, 0.0317, 0.0317, 0.0316, 0.0315, 0.0315, 0.0314, 0.0314,
    0.0313, 0.0313, 0.0313, 0.0312, 0.0312, 0.0312, 0.0312, 0.0311, 0.0311, 0.0311,
    0.0311, 0.0311, 0.0311, 0.0310, 0.0310, 0.0310, 0.0310, 0.0310, 0.0310, 0.0310,
    0.0310, 0.0310, 0.0310, 0.0309, 0.0309, 0.0309, 0.0309, 0.0309, 0.0309, 0.0309
]
rnn_val_nmse_db = [
    -18.0, -20.1, -22.1, -22.6, -22.7, -22.8, -22.9, -23.0, -23.0, -23.1,
    -23.1, -23.1, -23.1, -23.1, -23.2, -23.2, -23.2, -23.2, -23.2, -23.2,
    -23.2, -23.2, -23.2, -23.2, -23.2, -23.3, -23.3, -23.3, -23.3, -23.3,
    -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3,
    -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3, -23.3
]

# LSTM
lstm_val_loss = [
    0.0047, 0.0031, 0.0026, 0.0021, 0.0020, 0.0017, 0.0016, 0.0015, 0.0015, 0.0014,
    0.0014, 0.0014, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
    0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013
]
lstm_val_rmse = [
    0.0674, 0.0548, 0.0498, 0.0444, 0.0421, 0.0405, 0.0392, 0.0382, 0.0374, 0.0369,
    0.0364, 0.0361, 0.0358, 0.0356, 0.0354, 0.0353, 0.0352, 0.0351, 0.0351, 0.0350,
    0.0350, 0.0349, 0.0349, 0.0348, 0.0347, 0.0347, 0.0346, 0.0345, 0.0344, 0.0344,
]
lwm_pt_val_nmse_db = [
    -16.8, -18.1, -19.5, -20.1, -20.9, -21.3, -21.5, -21.6, -21.7, -21.8,
    -21.9, -21.9, -22.0, -22.1, -22.1, -22.1, -22.2, -22.2, -22.3, -22.3,
    -22.3, -22.3, -22.3, -22.3, -22.4, -22.4, -22.4, -22.4, -22.4, -22.4,
    -22.4, -22.4, -22.5, -22.5, -22.5, -22.5, -22.5, -22.6, -22.5, -22.6,
    -22.6, -22.6, -22.7, -22.6, -22.7, -22.7, -22.7, -22.7, -22.7, -22.7
]

# ---------------------------
# Pack all 7 models in one dict
# ---------------------------
metrics = {
    'GRU': {
        'val_loss': gru_val_loss,
        'val_rmse': gru_val_rmse,
        'val_nmse_db': gru_val_nmse_db
    },
    'RNN': {
        'val_loss': rnn_val_loss,
        'val_rmse': rnn_val_rmse,
        'val_nmse_db': rnn_val_nmse_db
    },
    'LSTM': {
        'val_loss': lstm_val_loss,
        'val_rmse': lstm_val_rmse,
        'val_nmse_db': lstm_val_nmse_db
    },
    'Transformer': {
        'val_loss': transformer_val_loss,
        'val_rmse': transformer_val_rmse,
        'val_nmse_db': transformer_val_nmse_db
    },
    'LWM Fine-tune': {
        'val_loss': lwm_ft_val_loss,
        'val_rmse': lwm_ft_val_rmse,
        'val_nmse_db': lwm_ft_val_nmse_db
    },
    'LWM Freeze-backbone': {
        'val_loss': lwm_fb_val_loss,
        'val_rmse': lwm_fb_val_rmse,
        'val_nmse_db': lwm_fb_val_nmse_db
    },
    'LWM Pre-trained FT': {
        'val_loss': lwm_pt_val_loss,
        'val_rmse': lwm_pt_val_rmse,
        'val_nmse_db': lwm_pt_val_nmse_db
    },
}

# Font sizes
TITLE_FS = 18
LABEL_FS = 16
TICK_FS  = 13
LEGEND_FS = 12

# ---------------------------
# Draw 3 subplots with all 7 models each (no markers)
# ---------------------------
fig, axes = plt.subplots(3, 1, figsize=(12, 14), sharex=True)

# Helper to plot one metric across all models (no markers)
def plot_metric(ax, metric_key, title, ylabel):
    ax.set_title(title, fontsize=TITLE_FS)
    for name, m in metrics.items():
        ax.plot(epochs, m[metric_key], label=name, lw=2)  # no marker
    ax.set_ylabel(ylabel, fontsize=LABEL_FS)
    ax.grid(True, linestyle='--', alpha=0.5)
    ax.tick_params(axis='both', labelsize=TICK_FS)
    ax.legend(fontsize=LEGEND_FS, ncol=3)

plot_metric(axes[0], 'val_loss', 'Validation Loss – 7-Model Comparison', 'Validation Loss')
plot_metric(axes[1], 'val_rmse', 'Validation RMSE – 7-Model Comparison', 'Validation RMSE')
plot_metric(axes[2], 'val_nmse_db', 'Validation NMSE (dB) – 7-Model Comparison', 'Validation NMSE (dB)')

axes[-1].set_xlabel('Epoch', fontsize=LABEL_FS)
axes[-1].set_xticks([10, 20, 30, 40, 50])

plt.tight_layout()
plt.show()

# %%
# Compute per-model lowest Validation NMSE(dB) and the overall lowest (first occurrence)
import pandas as pd

rows = []
for model, m in metrics.items():
    nmse = m['val_nmse_db']
    min_val = min(nmse)                 # most negative dB = best
    first_idx = nmse.index(min_val)     # first occurrence index
    rows.append({
        "Model": model,
        "Min NMSE (dB)": min_val,
        "Epoch (1-indexed)": first_idx + 1
    })

# Sort by the minimum NMSE(dB) ascending (most negative first)
summary_df = pd.DataFrame(rows).sort_values("Min NMSE (dB)").reset_index(drop=True)

# Overall lowest across all models (first occurrence)
overall = min(
    (
        {
            "Model": model,
            "Epoch (1-indexed)": m['val_nmse_db'].index(min(m['val_nmse_db'])) + 1,
            "Min NMSE (dB)": min(m['val_nmse_db'])
        }
        for model, m in metrics.items()
    ),
    key=lambda x: x["Min NMSE (dB)"]
)
overall_df = pd.DataFrame([overall])

# Print as plain pandas DataFrames
print("Per-model Lowest Validation NMSE(dB)")
print(summary_df.to_string(index=False))

print("\nOverall Lowest Validation NMSE(dB)")
print(overall_df.to_string(index=False))
# Out:
# Per-model Lowest Validation NMSE(dB)
#               Model  Min NMSE (dB)  Epoch (1-indexed)
#       LWM Fine-tune          -23.9                 50
#                 GRU          -23.4                 42
#                LSTM          -23.3                 44
#                 RNN          -23.3                 26
#  LWM Pre-trained FT          -22.7                 43
#         Transformer          -21.0                 50
# LWM Freeze-backbone          -17.9                 46
#
# Overall Lowest Validation NMSE(dB)
#         Model  Epoch (1-indexed)  Min NMSE (dB)
# LWM Fine-tune                 50          -23.9

# %%
import matplotlib.pyplot as plt

# Epoch indices
epochs = list(range(1, 151))

# Combined metrics for each model including train_loss
metrics = {
    'LWM_FromScratch': {
        'train_loss': [
            0.0137, 0.0039, 0.0026, 0.0020, 0.0018, 0.0016, 0.0016, 0.0015, 0.0015, 0.0014,
            0.0014, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012,
            0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0011, 0.0011,
            0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0010, 0.0010,
            0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
            0.0010, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
            0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0008, 0.0008, 0.0008, 0.0008,
            0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
            0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
            0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
            0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
            0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005,
            
        ],
        'val_loss': [
            0.0039, 0.0024, 0.0018, 0.0016, 0.0015, 0.0015, 0.0015, 0.0014, 0.0014, 0.0014,
            0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012,
            0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
            0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0011, 0.0011, 0.0011,
            0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0010, 0.0010,
            0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
            0.0010, 0.0010, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
            0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
            0.0009, 0.0009, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
            0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
            0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
            0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0007, 0.0007, 0.0007,
            0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
            0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
            0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
         ],
        
    },
    'LWM_Freeze': {
        'train_loss': [
            0.0601, 0.0075, 0.0073, 0.0070, 0.0066, 0.0063, 0.0061, 0.0059, 0.0058, 0.0057,
            0.0056, 0.0056, 0.0055, 0.0055, 0.0054, 0.0054, 0.0053, 0.0053, 0.0052, 0.0052,
            0.0051, 0.0050, 0.0050, 0.0049, 0.0049, 0.0049, 0.0049, 0.0048, 0.0048, 0.0048,
            0.0048, 0.0048, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047,
            0.0047, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046,
            0.0046, 0.0046, 0.0046, 0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0045,
            0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044,
            0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0043,
            0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043,
            0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0042, 0.0042, 0.0042, 0.0042,
            0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 
            0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0041, 0.0041,
            0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
            0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
            0.0041, 0.0041, 0.0041, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040,
            
        ],
        'val_loss': [
            0.0076, 0.0074, 0.0073, 0.0069, 0.0065, 0.0062, 0.0060, 0.0059, 0.0057, 0.0057,
            0.0056, 0.0055, 0.0055, 0.0054, 0.0054, 0.0053, 0.0053, 0.0052, 0.0051, 0.0050,
            0.0050, 0.0049, 0.0048, 0.0048, 0.0048, 0.0047, 0.0047, 0.0047, 0.0047, 0.0047,
            0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0046, 0.0045, 0.0045,
            0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0045, 0.0044, 0.0044,
            0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0044, 0.0043,
            0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0043, 0.0042,
            0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042, 0.0042,
            0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041, 0.0041,
            0.0041, 0.0041, 0.0041, 0.0041, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040,
            0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040, 0.0040,
            0.0040, 0.0040, 0.0039, 0.0039, 0.0039, 0.0039, 0.0039, 0.0039, 0.0039, 0.0039, 
            0.0039, 0.0039, 0.0039, 0.0039, 0.0039, 0.0039, 0.0039, 0.0039, 0.0039, 0.0039,
            0.0039, 0.0039, 0.0039, 0.0038, 0.0038, 0.0038, 0.0038, 0.0038, 0.0038, 0.0038,
            0.0038, 0.0038, 0.0038, 0.0038, 0.0038, 0.0038, 0.0038, 0.0038, 0.0038, 0.0038,
            
        ],
        
    },
    'LWM_Finetune': {
        'train_loss': [
            0.0164, 0.0050, 0.0034, 0.0026, 0.0022, 0.0020, 0.0020, 0.0019, 0.0018, 0.0018,
            0.0018, 0.0017, 0.0017, 0.0017, 0.0017, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016,
            0.0016, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0014,
            0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014,
            0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
            0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012,
            0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
            0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0011, 0.0011,
            0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
            0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
            0.0011, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
            0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
            0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
            0.0010, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
            0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,

        ],
        'val_loss': [
            0.0061, 0.0039, 0.0030, 0.0024, 0.0022, 0.0021, 0.0020, 0.0020, 0.0020, 0.0019,
            0.0019, 0.0019, 0.0018, 0.0018, 0.0018, 0.0018, 0.0017, 0.0017, 0.0017, 0.0017,
            0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017,
            0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016,
            0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016,
            0.0016, 0.0016, 0.0016, 0.0015, 0.0015, 0.0015, 0.0016, 0.0015, 0.0015, 0.0015,
            0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015,
            0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0014, 0.0015, 0.0014,
            0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014,
            0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014,
            0.0014, 0.0013, 0.0014, 0.0014, 0.0013, 0.0014, 0.0013, 0.0014, 0.0013, 0.0013,
            0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
            0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
            0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
            0.0012, 0.0012, 0.0013, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0013,
            
            
            
        ]
        
    }
}
# grid plus
# Marker styles for each model
markers = ['o', 's', '^']

# Font size settings
title_fontsize = 25
label_fontsize = 20
legend_fontsize = 20

# Create 4 subplots for train_loss, val_loss, val_rmse, val_nmse_db
fig, axes = plt.subplots(2, 1, figsize=(8, 10), sharex=True)

# Train Loss
axes[0].set_title('Subcarrier Train Loss Comparison', fontsize=title_fontsize)
for (name, m), marker in zip(metrics.items(), markers):
    axes[0].plot(epochs, m['train_loss'], label=name, lw=2, marker=marker, markevery=5)
axes[0].set_ylabel('Train Loss', fontsize=label_fontsize)
axes[0].legend(fontsize=legend_fontsize)
axes[0].tick_params(axis='both', labelsize=label_fontsize)

# Validation Loss
axes[1].set_title('Subcarrier Validation Loss Comparison', fontsize=title_fontsize)
for (name, m), marker in zip(metrics.items(), markers):
    axes[1].plot(epochs, m['val_loss'], label=name, lw=2, marker=marker, markevery=5)
axes[1].set_ylabel('Val Loss', fontsize=label_fontsize)
axes[1].legend(fontsize=legend_fontsize)
axes[1].tick_params(axis='both', labelsize=label_fontsize)

axes[1].set_ylim(bottom=0.0)

# X-axis settings for all subplots
for ax in axes:
    ax.set_xticks([10, 40, 70, 110, 150])
    ax.tick_params(axis='x', which='both', labelbottom=True)

# Only bottom subplot has the x-axis label
axes[-1].set_xlabel('Epoch', fontsize=label_fontsize)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## inference

# %%
from tabulate import tabulate

# Combine data1 and data2 into a single list
data_all = [
    ["LWM_Fine_tune", 42.51, 81.28, 0.32],
    ["GRU", 31.63, 60.48, 0.24],
    ["RNN", 32.04, 61.26, 0.24],
    ["LSTM", 31.20, 59.65, 0.23],
    ["Transformer", 35.82, 68.49, 0.27],
    ["LWM_freeze_backbone", 82.60, 157.94, 0.62],
    ["LWM_pretrained_Fine_tune", 83.47, 159.59, 0.62],
]

# Define column headers
headers = ["model", "total [s]", "/batch [ms]", "/sample [ms]"]

# Print the combined inference-time summary table
print("=== Inference-time summary ===")
print(tabulate(data_all, headers, tablefmt="github"))
# Out:
# === Inference-time summary ===
# | model                    |   total [s] |   /batch [ms] |   /sample [ms] |
# |--------------------------|-------------|---------------|----------------|
# | LWM_Fine_tune            |       42.51 |         81.28 |           0.32 |
# | GRU                      |       31.63 |         60.48 |           0.24 |
# | RNN                      |       32.04 |         61.26 |           0.24 |
# | LSTM                     |       31.2  |         59.65 |           0.23 |
# | Transformer              |       35.82 |         68.49 |           0.27 |
# | LWM_freeze_backbone      |       82.6  |        157.94 |           0.62 |
# | LWM_pretrained_Fine_tune |       83.47 |        159.59 |           0.62 |

# %% [markdown]
# # Trainable Parameters

# %%
import pandas as pd

# Original data
params_data = {
    "LWM_Fine_tune": 614_064,
    "LWM_Pretrained_Fine_tune": 608_912,
    "LWM_freeze_Backbone": 608_912,
    "RNN": 29_120,
    "GRU": 79_040,
    "LSTM": 104_000,
    "Transformer": 471_104
}

# Desired order from image
order = [
    "LWM_Fine_tune",
    "LWM_Pretrained_Fine_tune",
    "LWM_freeze_Backbone",
    "RNN",
    "GRU",
    "LSTM",
    "Transformer"
]

# Create DataFrame in the desired order
df_ordered = pd.DataFrame({
    "Model": order,
    "Total Parameters": [params_data[m] for m in order]
})

# Format with commas
df_ordered["Total Parameters"] = df_ordered["Total Parameters"].apply(lambda x: f"{x:,}")

# Print in console without index
print(df_ordered.to_string(index=False))
# Out:
#                    Model Total Parameters
#            LWM_Fine_tune          614,064
# LWM_Pretrained_Fine_tune          608,912
#      LWM_freeze_Backbone          608,912
#                      RNN           29,120
#                      GRU           79,040
#                     LSTM          104,000
#              Transformer          471,104
