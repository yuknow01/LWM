        -18.5, -18.5, -18.5, -18.5, -18.5, -18.6, -18.6, -18.5, -18.5, -18.5
    ]
}

# Average train time per epoch (s) for each model
avg_train_time = {
    "LWM_freeze_backbone": 831.55,
    "LWM_pretrained_Fine_tune": 994.75,
    "LWM_Fine_tune": 997.67,
    "gru": 419.13,
    "rnn": 380.71,
    "lstm": 426.37
}

# Plot: Validation NMSE curves (inverted y-axis)
plt.figure(figsize=(10, 6))
for model, vals in val_nmse_db.items():
    plt.plot(epochs, vals, label=model)
plt.xlabel('Epoch')
plt.ylabel('Validation NMSE (dB)')
plt.title('Option 1')
plt.gca().invert_yaxis()
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot: Avg training time per epoch
plt.figure(figsize=(8, 4))
models = list(avg_train_time.keys())
times = [avg_train_time[m] for m in models]
plt.bar(models, times)
plt.ylabel('Avg Train Time per Epoch (s)')
plt.title('Average Training Time per Epoch by Model')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Option 2

# %%
import matplotlib.pyplot as plt

# Epochs
epochs = list(range(1, 51))

# Validation NMSE (dB) per epoch for each model
val_nmse_db = {
    "LWM_freeze_backbone": [
        -14.2, -14.7, -14.9, -15.1, -15.2, -15.3, -15.4, -15.5,
        -15.6, -15.7, -15.7, -15.8, -15.8, -15.9, -15.9, -15.9,
        -16.0, -16.0, -16.0, -16.0, -16.1, -16.1, -16.1, -16.1,
        -16.1, -16.1, -16.1, -16.1, -16.1, -16.1, -16.1, -16.1,
        -16.2, -16.2, -16.2, -16.1, -16.2, -16.2, -16.2, -16.2,
        -16.2, -16.2, -16.2, -16.2, -16.2, -16.2, -16.2, -16.2,
        -16.2, -16.2
    ],
    "LWM_pretrained_fine_tune": [
        -16.6, -16.7, -17.2, -17.3, -17.1, -17.1, -16.8, -16.9,
        -17.1, -17.1, -17.2, -17.3, -17.3, -17.4, -17.5, -17.5,
        -17.5, -17.5, -17.5, -17.3, -17.2, -17.3, -17.4, -17.2,
        -17.2, -17.3, -17.3, -17.2, -17.2, -17.2, -17.2, -17.2,
        -17.3, -17.3, -17.2, -17.3, -17.3, -17.3, -17.3, -17.3,
        -17.4, -17.3, -17.4, -17.4, -17.3, -17.4, -17.3, -17.3,
        -17.3, -17.3
    ],
    "LWM_fine_tune": [
        -18.0, -18.4, -18.4, -18.5, -18.4, -18.5, -18.5, -18.5, -18.5, -18.3,
        -18.4, -18.3, -18.3, -18.4, -18.3, -18.3, -18.4, -18.3, -18.4, -18.4,
        -18.4, -18.4, -18.4, -18.4, -18.4, -18.4, -18.5, -18.5, -18.5, -18.5,
        -18.6, -18.6, -18.5, -18.4, -18.4, -18.6, -18.5, -18.5, -18.6, -18.6,
        -18.6, -18.6, -18.7, -18.7, -18.7, -18.6, -18.7, -18.7, -18.7, -18.6
    ],
    "gru": [
        -18.6, -20.7, -21.4, -21.7, -21.8, -21.9, -22.0, -22.1, -22.2, -22.1,
        -22.2, -22.2, -22.3, -22.3, -22.3, -22.3, -22.3, -22.3, -22.4, -22.5,
        -22.5, -22.5, -22.6, -22.6, -22.6, -22.6, -22.7, -22.7, -22.7, -22.7,
        -22.8, -22.7, -22.7, -22.7, -22.7, -22.6, -22.7, -22.5, -22.6, -22.7,
        -22.6, -22.6, -22.5, -22.6, -22.5, -22.6, -22.4, -22.5, -22.5, -22.5
    ],
    "rnn": [
        -21.5, -21.7, -22.2, -21.8, -22.0, -22.1, -22.1, -22.2, -22.3, -22.3,
        -22.3, -22.2, -22.2, -22.2, -22.1, -22.1, -22.1, -22.1, -22.2, -22.1,
        -22.1, -22.2, -22.3, -22.3, -22.3, -22.5, -22.4, -22.5, -22.6, -22.6,
        -22.7, -22.7, -22.7, -22.8, -22.8, -22.8, -22.8, -22.8, -22.8, -22.8,
        -22.8, -22.8, -22.8, -22.9, -22.8, -22.8, -22.8, -22.8, -22.8, -22.8
    ],
    "lstm": [
        -16.7, -17.8, -18.1, -18.8, -19.6, -20.3, -20.7, -21.0, -21.1, -21.2,
        -21.4, -21.5, -21.5, -21.5, -21.5, -21.7, -21.9, -21.9, -22.0, -22.0,
        -22.0, -22.0, -22.1, -22.2, -22.3, -22.3, -22.4, -22.3, -22.4, -22.4,
        -22.4, -22.4, -22.4, -22.2, -22.4, -22.6, -22.3, -22.4, -22.4, -22.4,
        -22.4, -22.4, -22.5, -22.6, -22.4, -22.4, -22.4, -22.4, -22.4, -22.4
    ]
}

# Average train time per epoch (s)
avg_train_time = {
    "LWM_freeze_backbone": 809.79,
    "LWM_pretrained_fine_tune": 975.65,
    "LWM_fine_tune": 972.45,
    "gru": 409.79,
    "rnn": 372.67,
    "lstm": 405.81
}

# Plot: Validation NMSE curves (inverted y-axis)
plt.figure(figsize=(10, 6))
for model, vals in val_nmse_db.items():
    plt.plot(epochs, vals, label=model)
plt.xlabel('Epoch')
plt.ylabel('Validation NMSE (dB)')
plt.title('Option2')
plt.gca().invert_yaxis()
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot: Avg training time per epoch
plt.figure(figsize=(8, 4))
models = list(avg_train_time.keys())
times = [avg_train_time[m] for m in models]
plt.bar(models, times)
plt.ylabel('Avg Train Time per Epoch (s)')
plt.title('Average Training Time per Epoch by Model')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # option 3

# %%
import matplotlib.pyplot as plt

# Epochs
epochs = list(range(1, 51))

# Validation NMSE (dB) for each epoch
val_nmse_db = {
    "LWM_freeze_backbone": [
        -15.9, -16.5, -16.7, -16.9, -16.9, -17.0, -17.1, -17.2, -17.3, -17.4,
        -17.5, -17.6, -17.6, -17.7, -17.7, -17.8, -17.8, -17.8, -17.9, -17.9,
        -18.0, -18.0, -18.0, -18.1, -18.1, -18.1, -18.2, -18.2, -18.2, -18.3,
        -18.3, -18.3, -18.3, -18.3, -18.3, -18.3, -18.4, -18.4, -18.4, -18.4,
        -18.4, -18.4, -18.4, -18.4, -18.4, -18.4, -18.4, -18.5, -18.5, -18.5
    ],
    "LWM_pretrained_Fine_tune": [
        -19.1, -20.4, -21.2, -21.5, -21.7, -21.8, -21.9, -22.0,
        -22.2, -22.2, -22.3, -22.3, -22.4, -22.4, -22.5, -22.5,
        -22.4, -22.5, -22.5, -22.5, -22.6, -22.6, -22.7, -22.7,
        -22.8, -22.8, -22.8, -22.8, -22.8, -22.8, -22.8, -22.8,
        -22.9, -22.9, -22.9, -22.9, -23.0, -22.9, -23.0, -23.1,
        -23.1, -23.1, -23.1, -23.1, -23.2, -23.2, -23.2, -23.2,
        -23.2, -23.2
    ],
    "LWM_Fine_tune": [
        -20.0, -21.1, -21.5, -21.7, -21.8, -21.9, -22.0, -22.0, -22.2, -22.3,
        -22.5, -22.5, -22.6, -22.7, -22.8, -22.9, -23.0, -23.0, -23.1, -23.1,
        -23.2, -23.3, -23.3, -23.4, -23.4, -23.5, -23.6, -23.5, -23.6, -23.6,
        -23.7, -23.7, -23.7, -23.7, -23.8, -23.8, -23.8, -23.9, -23.9, -23.9,
        -23.9, -24.0, -23.9, -24.0, -23.9, -24.0, -24.0, -24.1, -23.9, -24.0
    ],
    "gru": [
        -18.8, -20.6, -21.0, -20.9, -21.1, -21.6, -21.6, -21.8, -21.8, -21.8,
        -21.8, -22.0, -22.0, -22.1, -21.9, -22.2, -22.2, -22.3, -21.9, -22.3,
        -22.4, -21.1, -22.5, -22.5, -22.5, -22.6, -22.7, -22.4, -22.8, -22.9,
        -22.9, -23.0, -22.8, -23.1, -23.2, -23.2, -23.2, -23.3, -23.2, -22.6,
        -23.4, -23.3, -23.4, -23.3, -23.4, -23.5, -23.4, -23.5, -23.4, -23.6
    ],
    "rnn": [
        -21.0, -21.6, -21.4, -21.5, -21.5, -21.6, -21.6, -21.6, -21.6, -21.6,
        -21.7, -21.7, -21.7, -21.7, -21.7, -21.7, -21.7, -21.7, -21.8, -21.8,
        -21.8, -21.8, -21.8, -21.9, -22.0, -22.0, -22.0, -22.0, -22.1, -22.1,
        -22.1, -22.1, -22.1, -22.2, -22.2, -22.2, -22.2, -22.1, -22.2, -22.2,
        -22.2, -22.3, -22.3, -22.3, -22.3, -22.3, -22.4, -22.4, -22.4, -22.4
    ],
    "lstm": [
        -16.4, -17.3, -18.0, -19.0, -19.6, -20.4, -20.7, -21.0, -21.2, -21.3,
        -21.4, -21.5, -21.6, -21.6, -21.7, -21.7, -21.8, -21.8, -21.9, -21.9,
        -22.0, -22.0, -22.2, -22.2, -22.2, -22.3, -22.3, -22.3, -22.3, -22.4,
        -22.4, -22.4, -22.4, -22.3, -22.4, -22.4, -22.5, -22.5, -22.5, -22.6,
        -22.6, -22.6, -22.7, -22.7, -22.6, -22.6, -22.8, -22.8, -22.8, -22.8
    ]
}

# Average training time per epoch (seconds)
avg_train_time = {
    "LWM_freeze_backbone": 813.34,
    "LWM_pretrained_Fine_tune": 975.17,
    "LWM_Fine_tune": 988.69,
    "gru": 412.21,
    "rnn": 376.74,
    "lstm": 405.36
}

# Plot validation NMSE (inverted y-axis)
plt.figure(figsize=(10, 6))
for model_name, values in val_nmse_db.items():
    plt.plot(epochs, values, label=model_name)
plt.xlabel('Epoch')
plt.ylabel('Validation NMSE (dB)')
plt.title('Option 3')
plt.legend()
plt.gca().invert_yaxis()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot average training time per epoch as a bar chart
plt.figure(figsize=(8, 4))
models = list(avg_train_time.keys())
times = [avg_train_time[m] for m in models]
plt.bar(models, times)
plt.ylabel('Avg Train Time per Epoch (s)')
plt.title('Average Training Time per Epoch by Model')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
